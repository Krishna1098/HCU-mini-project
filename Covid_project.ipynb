# %%
import pandas as pd
import numpy as np
import seaborn as ss
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
# %matplotlib inline
plt.rcParams['figure.figsize']=14,6
import folium

# %%
cd '/home/vry/Downloads/covid/'
# Out:
# /home/vry/Downloads/covid

# %%
df=pd.read_csv("Data.csv")
df.head()
# Out:
#    Sno                     State/UT  Confirmed Cases  Active Cases  \
# 0    1  Andaman and Nicobar Islands             7070           131
# 1    2               Andhra Pradesh          1728577        138912
# 2    3            Arunachal Pradesh            28382          3843
# 3    4                        Assam           424385         51881
# 4    5                        Bihar           710199         11431
#
#    Cured/Discharged  Death
# 0              6820    119
# 1           1578452  11213
# 2             24420    119
# 3            368981   3523
# 4            693472   5296

# %%
df.columns
# Out:
# Index(['Sno', 'State/UT', 'Confirmed Cases', 'Active Cases',
#        'Cured/Discharged', 'Death'],
#       dtype='object')

# %% [markdown]
# # Data description

# %%
df.describe()
# Out:
#              Sno  Confirmed Cases  Active Cases  Cured/Discharged  \
# count  36.000000     3.600000e+01      36.00000      3.600000e+01
# mean   18.500000     7.937319e+05   45444.25000      7.388238e+05
# std    10.535654     1.137073e+06   76094.03898      1.062264e+06
# min     1.000000     7.070000e+03     131.00000      6.820000e+03
# 25%     9.750000     4.896150e+04    5932.75000      3.993325e+04
# 50%    18.500000     3.821575e+05   12059.50000      3.481765e+05
# 75%    27.250000     9.518105e+05   31137.50000      9.142060e+05
# max    36.000000     5.791413e+06  286819.00000      5.486206e+06
#
#               Death
# count     36.000000
# mean    9463.944444
# std    17091.535925
# min        4.000000
# 25%      603.500000
# 50%     3757.500000
# 75%    10220.750000
# max    97394.000000

# %% [markdown]
# # Visualization

# %%
ss.pairplot(df)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar',x='State/UT',y='Death')
plt.show()

# %%
df.plot(kind='bar',x='State/UT',y='Active Cases')
plt.show()

# %%
df['Total cases']=df['Confirmed Cases']+df['Active Cases']+df['Cured/Discharged']

# %%
df
# Out:
#     Sno                                  State/UT  Confirmed Cases  \
# 0     1               Andaman and Nicobar Islands             7070
# 1     2                            Andhra Pradesh          1728577
# 2     3                         Arunachal Pradesh            28382
# 3     4                                     Assam           424385
# 4     5                                     Bihar           710199
# 5     6                                Chandigarh            60399
# 6     7                              Chhattisgarh           976760
# 7     8  Dadra and Nagar Haveli and Daman and Diu            10345
# 8     9                                     Delhi          1427926
# 9    10                                       Goa           157847
# 10   11                                   Gujarat           813270
# 11   12                                   Haryana           760019
# 12   13                          Himachal Pradesh           193137
# ...

# %%
df.plot(kind='bar',x='State/UT',y='Total cases')
plt.show()

# %%
fig=plt.figure(figsize=(14,6),dpi=200)
axes=fig.add_axes([0,0,1,1])
axes.bar(df['State/UT'],df['Total cases'])
axes.set_title("Total Cases in India")
axes.set_xlabel("Name of State / UT")
axes.set_ylabel("Total Cases")
plt.show()

# %%
df['Total cases'].sum()
# Out:
# 56807998

# %%
df.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# ...

# %%
df.plot(kind='scatter',x='State/UT',y='Total cases')
# Out:
# <AxesSubplot:xlabel='State/UT', ylabel='Total cases'>

# %%
dd=pd.read_excel('Indian Coordinates.xlsx')
dd
# Out:
#                                 State/UT   Latitude  Longitude
# 0                   Andaman And Nicobar   11.667026  92.735983
# 1                         Andhra Pradesh  14.750429  78.570026
# 2                     Arunachal Pradesh   27.100399  93.616601
# 3                                 Assam   26.749981  94.216667
# 4                                 Bihar   25.785414  87.479973
# 5                            Chandigarh   30.719997  76.780006
# 6                          Chhattisgarh   22.090420  82.159987
# 7                Dadra And Nagar Haveli   20.266578  73.016618
# 8                                  Delhi  28.669993  77.230004
# 9                                   Goa   15.491997  73.818001
# 10                               Haryana  28.450006  77.019991
# 11                     Himachal Pradesh   31.100025  77.166597
# 12  Union Territory of Jammu and Kashmir  33.450000  76.240000
# 13                            Jharkhand   23.800393  86.419986
# ...

# %%
df_full=pd.merge(dd,df,on='State/UT')
df_full
# Out:
#           State/UT   Latitude  Longitude  Sno  Confirmed Cases  Active Cases  \
# 0   Andhra Pradesh  14.750429  78.570026    2          1728577        138912
# 1            Delhi  28.669993  77.230004    9          1427926          8748
# 2          Haryana  28.450006  77.019991   12           760019         12688
# 3        Karnataka  12.570381  76.919997   16          2653446        286819
# 4           Kerala   8.900373  76.569993   17          2584853        184699
# 5      Maharashtra  19.250232  73.160175   21          5791413        207813
# 6           Punjab  31.519974  75.980003   28           574114         28673
# 7        Rajasthan  26.449999  74.639981   29           943494         27408
# 8       Tamil Nadu  12.920386  79.150042   31          2172751        280426
# 9    Uttar Pradesh  27.599981  78.050006   34          1695212         25546
# 10     Uttarakhand  30.320409  78.050006   35           332067         22530
#
#     Cured/Discharged  Death  Total cases
# ...

# %%
map=folium.Map(location=[20,70],zoom_start=10,tiles='Stamenterrain')

for lat,long,value, name in zip(df_full['Latitude'],df_full['Longitude'],df_full['Active Cases'],df_full['State/UT']):
    folium.CircleMarker([lat,long],radius=value*2.4,popup=('<strong>State</strong>: '+str(name).capitalize()+'<br>''<strong>Total cases</strong>: ' + str(value)+ '<br>'),color='red',fill_color='red',fill_opacity=0).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
